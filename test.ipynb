# %% [markdown]
# # Generate text with RuGPTs in huggingface
# How to generate text with pretrained RuGPTs models with huggingface.
#
# This notebook is valid for all RuGPTs models except RuGPT3XL.
# ## Install env

# %%
# !pip3 install transformers==3.5.0
# Out:
# Collecting transformers==3.5.0
#   Downloading https://files.pythonhosted.org/packages/9c/34/fb092588df61bf33f113ade030d1cbe74fb73a0353648f8dd938a223dce7/transformers-3.5.0-py3-none-any.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 11.6MB/s
# Collecting sentencepiece==0.1.91
#   Downloading https://files.pythonhosted.org/packages/f2/e2/813dff3d72df2f49554204e7e5f73a3dc0f0eb1e3958a4cad3ef3fb278b7/sentencepiece-0.1.91-cp37-cp37m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 32.2MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.5.0) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.5.0) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.5.0) (2.23.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 46.6MB/s
# Collecting tokenizers==0.9.3
#   Downloading https://files.pythonhosted.org/packages/7b/ac/f5ba028f0f097d855e1541301e946d4672eb0f30b6e25cb2369075f916d2/tokenizers-0.9.3-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 37.3MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.5.0) (1.19.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.5.0) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.5.0) (20.9)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers==3.5.0) (3.12.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.5.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.5.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.5.0) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.5.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.5.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.5.0) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.5.0) (2.4.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->transformers==3.5.0) (54.0.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=2cb6627c72476adb491366a75790327f2f1f0bd6823dafbe24f04e2cf1da9b70
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sentencepiece, sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.91 tokenizers-0.9.3 transformers-3.5.0

# %%
# !git clone  https://github.com/sberbank-ai/ru-gpts
# Out:
# Cloning into 'ru-gpts'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 595 (delta 56), reused 36 (delta 18), pack-reused 505
# Receiving objects: 100% (595/595), 349.36 KiB | 1.43 MiB/s, done.
# Resolving deltas: 100% (356/356), done.

# %% [markdown]
# ## Generate

# %%
import numpy as np
import torch

# %%
np.random.seed(42)
torch.manual_seed(42)

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
def load_tokenizer_and_model(model_name_or_path):
  return GPT2Tokenizer.from_pretrained(model_name_or_path), GPT2LMHeadModel.from_pretrained(model_name_or_path).cuda()


def generate(
    model, tok, text,
    do_sample=True, max_length=20, repetition_penalty=7.0,
    top_k=5, top_p=0.95, temperature=1,
    num_beams=None,
    no_repeat_ngram_size=10
    ):
  input_ids = tok.encode(text, return_tensors="pt").cuda()
  out = model.generate(
      input_ids.cpu(),
      max_length=max_length,
      repetition_penalty=repetition_penalty,
      do_sample=do_sample,
      top_k=top_k, top_p=top_p, temperature=temperature,
      num_beams=num_beams, no_repeat_ngram_size=no_repeat_ngram_size
      )
  return list(map(tok.decode, out))

# %% [markdown]
# ### RuGPT2Large

# %%
tok, model = load_tokenizer_and_model("sberbank-ai/rugpt2large")
generated = generate(model, tok, "Александр Сергеевич Пушкин родился в ", num_beams=10)
generated[0]

# %% [markdown]
# ### RuGPT3Small

# %%
tok, model = load_tokenizer_and_model("sberbank-ai/rugpt3small_based_on_gpt2")
generated = generate(model, tok, "Александр Сергеевич Пушкин родился в ", num_beams=10)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-b370517791d1> in <module>()
# ----> 1 tok, model = load_tokenizer_and_model("sberbank-ai/rugpt3small_based_on_gpt2")
#       2 generated = generate(model, tok, "Александр Сергеевич Пушкин родился в ", num_beams=10)
#
# <ipython-input-4-aa0753a5858f> in load_tokenizer_and_model(model_name_or_path)
#       1 def load_tokenizer_and_model(model_name_or_path):
# ----> 2   return GPT2Tokenizer.from_pretrained(model_name_or_path), GPT2LMHeadModel.from_pretrained(model_name_or_path).cuda()
#       3
#       4
#       5 def generate(
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in cuda(self, device)
#     461             Module: self
#     462         """
# --> 463         return self._apply(lambda t: t.cuda(device))
#     464
#     465     def cpu(self: T) -> T:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     357     def _apply(self, fn):
#     358         for module in self.children():
# --> 359             module._apply(fn)
#     360
#     361         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     379                 # `with torch.no_grad():`
#     380                 with torch.no_grad():
# --> 381                     param_applied = fn(param)
#     382                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     383                 if should_use_set_data:
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in <lambda>(t)
#     461             Module: self
#     462         """
# --> 463         return self._apply(lambda t: t.cuda(device))
#     464
#     465     def cpu(self: T) -> T:
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     170         # This function throws if there's a driver initialization error, no GPUs
#     171         # are found or any other error occurs
# --> 172         torch._C._cuda_init()
#     173         # Some of the queued calls may reentrantly call _lazy_init();
#     174         # we need to just return without initializing in that case.
#
# RuntimeError: No CUDA GPUs are available

# %%
generated[0]
# Out:
# 'Александр Сергеевич Пушкин родился в  1824 г. в семье поэта и драматурга Александра Сергеевича Пушкина (1825-1894) и Марии Александровны Пушкиной (1828-1897). В 17 лет он поступил на юридический факультет Московского'

# %% [markdown]
# ### RuGPT3Medium

# %%
tok, model = load_tokenizer_and_model("sberbank-ai/rugpt3medium_based_on_gpt2")
generated = generate(model, tok, "Александр Сергеевич Пушкин родился в ", num_beams=10)

# %%
generated[0]
# Out:
# 'Александр Сергеевич Пушкин родился в  1799 году. Его отец, Александр Сергеевич Пушкин, был генерал-адъютантом и воспитателем великого поэта Александра Сергеевича Грибоедова (1795–1829). В 1811 году он поступил'

# %% [markdown]
# ### RuGPT3Large

# %%
tok, model = load_tokenizer_and_model("sberbank-ai/rugpt3large_based_on_gpt2")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1713123.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1270925.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=609.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=3141928084.0, style=ProgressStyle(descr…

# %%
generated = generate(model, tok, "Мне хочется взять тебя и крепко", num_beams=13)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-7bb9ba498b97> in <module>()
# ----> 1 generated = generate(model, tok, "Мне хочется взять тебя и крепко", num_beams=13)
#
# <ipython-input-11-21a5fc0ea7ab> in generate(model, tok, text, do_sample, max_length, repetition_penalty, top_k, top_p, temperature, num_beams, no_repeat_ngram_size)
#      17       do_sample=do_sample,
#      18       top_k=top_k, top_p=top_p, temperature=temperature,
# ---> 19       num_beams=num_beams, no_repeat_ngram_size=no_repeat_ngram_size
#      20       )
#      21   return list(map(tok.decode, out))
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py in generate(self, input_ids, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, num_return_sequences, decoder_start_token_id, use_cache, **model_kwargs)
#     594                 pad_token_id=pad_token_id,
#     595                 eos_token_id=eos_token_id,
# --> 596                 **model_kwargs,
#     597             )
#     598
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py in beam_sample(self, input_ids, beam_scorer, logits_processor, logits_warper, max_length, pad_token_id, eos_token_id, **model_kwargs)
#    1175             )
#    1176             if model_kwargs["past"] is not None:
# -> 1177                 model_kwargs["past"] = self._reorder_cache(model_kwargs["past"], beam_idx)
#    1178
#    1179             if beam_scorer.is_done:
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py in _reorder_cache(past, beam_idx)
#     216         subclasses of :class:`~transformers.PreTrainedModel`.
#     217         """
# --> 218         return tuple(layer_past.index_select(1, beam_idx) for layer_past in past)
#     219
#     220     def _get_logits_warper(
#
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py in <genexpr>(.0)
#     216         subclasses of :class:`~transformers.PreTrainedModel`.
#     217         """
# --> 218         return tuple(layer_past.index_select(1, beam_idx) for layer_past in past)
#     219
#     220     def _get_logits_warper(
#
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 14.76 GiB total capacity; 13.63 GiB already allocated; 9.75 MiB free; 13.83 GiB reserved in total by PyTorch)

# %%
generated[0]
# Out:
# 'Мне хочется взять тебя и крепко-крепко прижать к себе, но я не могу этого сделать. Потому что ты слишком красива для меня».\n\n«Я тоже так думаю»,\xa0— ответила она со слезами на глазах.\n\nОн поцеловал ее в макушку: «Ты самая красивая девушка из всех, кого я когда-либо видел! Я люблю тебя!»\n\nОни поцеловались еще раз — сначала нежно, а потом все сильнее прижимаясь друг к другу. Они целовались до тех пор, пока их тела не стали такими же горячими, как раскаленные угли костра. Когда они наконец оторвались друг от друга, у них обоих было такое чувство, словно кто-то вылил на них ведро расплавленного свинца. Но это был всего лишь поцелуй…\n\n* * *\n\nЧерез несколько часов после того, как он вернулся домой, его разбудил телефонный звонок. На другом конце провода ему сказали, что какой-то человек хочет поговорить с ним по очень важному делу. Он сразу понял, что речь идет о том самом деле, которое привело его сюда сегодня утром. В трубке слышалось какое-то шуршание; казалось, будто там шевелятся какие-то невидимые насекомые. Потом раздался щелчок выключателя рядом с телефоном (это означало, что абонент находится вне зоны действия сети), и телефон снова ожил.\n\nНа этот раз звонивший оказался мужчиной лет сорока пяти или даже чуть старше. У него были густые седеющие волосы зачесаны назад таким образом, чтобы образовать нечто вроде короны над лысым черепом. Одет он был в темно-синий костюм цвета морской волны без каких бы то ни было следов гламурного шика. Из нагрудного кармана пиджака выглядывал белый пластиковый прямоугольник размером примерно два на три дюйма[1 - 1 дюйм = 2,54 см.]. По всей видимости, эта штуковина была чем-то вроде портативного радиотелефонного переговорного устройства стандарта DECT.[2 - Дистанционное радиоэлектронное подслушивающее устройство.] Судя по всему, незнакомец принадлежал к тому редкому типу людей, которые никогда не упускают случая обзавестись каким-нибудь диковинным аппаратом вместо привычного сотового телефона. Впрочем, если судить по внешнему виду незнакомца, можно было предположить, что им движет отнюдь не только забота об удобстве своей персоны. Во всяком случае, одет он был весьма экстравагантно именно потому, что'
